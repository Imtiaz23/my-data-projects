# %% [markdown]
# ##Loading the Data

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# Your file will probably be called this, if you used the regular Kaggle download.
# !unzip -q /gdrive/MyDrive/comp8220data/living-thing-classification-coarse.zip     # CHANGE DIRECTORY
# Out:
# replace info.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# y

# %%
import json
import numpy as np
import pandas as pd
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt

# %%
batch_size = 64
img_size = 112
fine_grain = False
num_classes = 50 if fine_grain else 8

root = Path('')

# %%
def load_target_names(path='info.json'):
    with open(path) as f:
        info = json.load(f)
    return info['fine'], info['coarse']

def load_image(file_path, image_size=112):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, [image_size, image_size])
    return img

def create_dataset_tf(split, fine_grained, batch_size=32, image_size=112):
  df = pd.read_csv(root / f"{split}.csv")
  file_paths = df.filename.map(lambda fn: str(root / split / fn))
  labels = df.fine if fine_grained else df.coarse

  dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))
  dataset = dataset.map(lambda x, y: (load_image(x, image_size=image_size), y))
  dataset = dataset.batch(batch_size)
  dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
  return dataset


def create_dataset_sklearn(split, fine_grained, image_size=48, percent=0.1):
  dataset = create_dataset_tf(split=split, fine_grained=fine_grained, batch_size=1000, image_size=image_size)
  dataset = dataset.map(lambda x, y: (tf.image.rgb_to_grayscale(x), y))
  X = None
  Y = None
  n_batches = int(len(dataset) * percent)
  for x,y in dataset.take(n_batches):
    x, y = x.numpy(), y.numpy()
    x = x.reshape(x.shape[0], -1)
    X = x if X is None else np.vstack([X, x])
    Y = y if Y is None else np.hstack([Y, y])

  return X, Y

# %%
fine_names, coarse_names = load_target_names()
print(coarse_names)
# Out:
# ['Aves', 'Reptilia', 'Mammalia', 'Arachnida', 'Magnoliopsida', 'Insecta', 'Liliopsida', 'Pinopsida']

# %% [markdown]
# ## Creating Tensorflow Data

# %%
train_ds = create_dataset_tf('train', fine_grained=False, batch_size=batch_size)
val_ds = create_dataset_tf('val', fine_grained=False, batch_size=batch_size)

# %%
train_ds = train_ds.map(lambda x,y: (tf.keras.applications.xception.preprocess_input(x), y))
val_ds = val_ds.map(lambda x,y: (tf.keras.applications.xception.preprocess_input(x), y))

# %% [markdown]
# # Barebone Conv2d

# %%
from functools import partial
DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same", activation="relu", kernel_initializer="he_normal")
model_barebone = tf.keras.Sequential([
    DefaultConv2D(filters = 20, kernel_size=6, input_shape=[112,112,3]),
    tf.keras.layers.MaxPool2D(),
    DefaultConv2D(filters = 40),
    DefaultConv2D(filters = 40),
    tf.keras.layers.MaxPool2D(),
    DefaultConv2D(filters = 200),
    DefaultConv2D(filters = 200),
    tf.keras.layers.MaxPool2D(),
    DefaultConv2D(filters = 400),
    DefaultConv2D(filters = 400),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=200, activation="relu", kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(units=70, activation="relu", kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=50, activation="softmax")
])

model_barebone.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 112, 112, 40)      4360
#
#  max_pooling2d_5 (MaxPooling  (None, 56, 56, 40)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 100)       36100
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 100)       90100
#
#  max_pooling2d_6 (MaxPooling  (None, 28, 28, 100)      0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 200)       180200
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 200)       360200
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 200)      0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 400)       720400
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 400)       1440400
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 400)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 19600)             0
#
#  dense_8 (Dense)             (None, 200)               3920200
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense_9 (Dense)             (None, 70)                14070
#
#  dropout_3 (Dropout)         (None, 70)                0
#
#  dense_10 (Dense)            (None, 50)                3550
#
# =================================================================
# Total params: 6,769,580
# Trainable params: 6,769,580
# Non-trainable params: 0
# _________________________________________________________________

# %%
CustomAdam = partial(tf.keras.optimizers.Adam, learning_rate=0.0001, epsilon=1e-3)
model.compile(optimizer=CustomAdam(), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs = 6, verbose=1)
# Out:
# Epoch 1/6
# 1563/1563 [==============================] - 276s 173ms/step - loss: 3.7197 - accuracy: 0.0438 - val_loss: 3.4489 - val_accuracy: 0.0794
# Epoch 2/6
# 1563/1563 [==============================] - 237s 151ms/step - loss: 3.4005 - accuracy: 0.0870 - val_loss: 3.2013 - val_accuracy: 0.1279
# Epoch 3/6
# 1563/1563 [==============================] - 203s 130ms/step - loss: 3.2083 - accuracy: 0.1205 - val_loss: 3.0858 - val_accuracy: 0.1532
# Epoch 4/6
# 1563/1563 [==============================] - 238s 153ms/step - loss: 3.0548 - accuracy: 0.1496 - val_loss: 2.9593 - val_accuracy: 0.1831
# Epoch 5/6
# 1563/1563 [==============================] - 205s 131ms/step - loss: 2.9058 - accuracy: 0.1833 - val_loss: 2.8452 - val_accuracy: 0.2129
# Epoch 6/6
# 1563/1563 [==============================] - 203s 130ms/step - loss: 2.7661 - accuracy: 0.2143 - val_loss: 2.7899 - val_accuracy: 0.2343

# %%
test_ds = create_dataset_tf('test', fine_grained=True, batch_size=batch_size)

# %%
y_pred_fine = model.predict(test_ds)
# Out:
# 782/782 [==============================] - 94s 120ms/step

# %%
y_pred_classes = np.argmax(y_pred_fine, axis=1)

# %%
N = 50000     # num elements in test.csv
test_csv = pd.read_csv(root / f"test.csv")
test_csv.loc[:,"fine"] = y_pred_classes
test_csv = test_csv.drop(columns=['coarse'])
pred_file = "/gdrive/MyDrive/comp8220data/47506067-deep-fine.csv"  # CHANGE DIRECTORY, FILENAME as appropriate
test_csv.to_csv(pred_file)

# %% [markdown]
# 1. Error in Softmax layer need to use sparse_categorical_crossentropy

# %%
total_elements = tf.data.experimental.cardinality(val_ds).numpy()
print(total_elements)
num_elements_to_take = int(0.5 * total_elements)
#train_ds = train_ds.take(num_elements_to_take)
val_ds = val_ds.take(num_elements_to_take)
# Out:
# 782

# %%
total_elements = tf.data.experimental.cardinality(train_ds).numpy()
print(total_elements)
# Out:
# 1563

# %% [markdown]
# # First Try:
# 1. resnet with
# 2. Try using learning rate scheduler, epsilon scheduler

# %%
# Load the ResNet50 model without the top (fully connected) layers
base_model = tf.keras.applications.xception.Xception(weights='imagenet', include_top=False)
data_augmentation = tf.keras.Sequential(
    [tf.keras.layers.RandomFlip(mode="horizontal", seed=42),
     tf.keras.layers.RandomFlip(mode="vertical", seed=42),
     tf.keras.layers.RandomZoom(0.2,0.2),
     tf.keras.layers.RandomRotation(factor=(-0.2,0.2), seed=42)]
)
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    data_augmentation,
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=256, activation="relu"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=8, activation="softmax")
])
model.build(input_shape=(None, 112, 112, 3))

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 112, 112, 3)       0
#
#  xception (Functional)       (None, None, None, 2048)  20861480
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_14 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_8 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 21,420,464
# Trainable params: 558,728
# Non-trainable params: 20,861,736
# _________________________________________________________________

# %%
from functools import partial
CustomAdam = partial(tf.keras.optimizers.Adam, learning_rate=0.0001, epsilon=1e-3)
model.compile(optimizer=CustomAdam(), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
checkpoint_path = "/gdrive/MyDrive/comp8220data/XceptionPreprocessInitialize"
#checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback_initial = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs = 3,callbacks=[cp_callback_initial], verbose=1)
# Out:
# Epoch 1/3
# 1563/1563 [==============================] - ETA: 0s - loss: 2.6180 - accuracy: 0.3759
# Epoch 1: saving model to /gdrive/MyDrive/comp8220data/XceptionPreprocessInitialize
# 1563/1563 [==============================] - 256s 154ms/step - loss: 2.6180 - accuracy: 0.3759 - val_loss: 1.8160 - val_accuracy: 0.4498
# Epoch 2/3
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.6169 - accuracy: 0.4502
# Epoch 2: saving model to /gdrive/MyDrive/comp8220data/XceptionPreprocessInitialize
# 1563/1563 [==============================] - 239s 153ms/step - loss: 1.6169 - accuracy: 0.4503 - val_loss: 1.5182 - val_accuracy: 0.4542
# Epoch 3/3
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.4932 - accuracy: 0.4546
# Epoch 3: saving model to /gdrive/MyDrive/comp8220data/XceptionPreprocessInitialize
# 1563/1563 [==============================] - 236s 151ms/step - loss: 1.4932 - accuracy: 0.4546 - val_loss: 1.4912 - val_accuracy: 0.4537

# %%
for layer in base_model.layers[8:]:
    layer.trainable = True

# %%
from functools import partial
CustomAdam = partial(tf.keras.optimizers.Adam, learning_rate=0.00003, epsilon=1e-3)
model.compile(optimizer=CustomAdam(), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
checkpoint_path = "/gdrive/MyDrive/comp8220data/XceptionPreprocessTest10Layer"
#checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
weight_for_0 = (2 / 20069) * (12500)
weight_for_1 = (1 / 1891) * (12500)
weight_for_2 = (1 / 1957) * (12500)
weight_for_3 = (1 / 2015) * (12500)
weight_for_4 = (2 / 36062) * (12500)
weight_for_5 = (2 / 26082) * (12500)
weight_for_6 = (1 / 9960) * (12500)
weight_for_7 = (1 / 1961) * (12500)
class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3,4: weight_for_4, 5: weight_for_5,6: weight_for_6, 7: weight_for_7}

# %%
model.load_weights('/gdrive/MyDrive/comp8220data/XceptionPreprocessInitialize')

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs = 40, callbacks=[cp_callback], verbose=1)
# Out:
# Epoch 1/40
#  394/1563 [======>.......................] - ETA: 4:41 - loss: 1.2862 - accuracy: 0.5614

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs = 40, callbacks=[cp_callback], verbose=1)
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - ETA: 0s - loss: 1.3717 - accuracy: 0.5231
# Epoch 1: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 425s 244ms/step - loss: 1.3717 - accuracy: 0.5231 - val_loss: 1.1405 - val_accuracy: 0.5986
# Epoch 2/40
# 1563/1563 [==============================] - ETA: 0s - loss: 1.1006 - accuracy: 0.6129
# Epoch 2: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 1.1006 - accuracy: 0.6129 - val_loss: 1.0299 - val_accuracy: 0.6337
# Epoch 3/40
# 1563/1563 [==============================] - ETA: 0s - loss: 1.0006 - accuracy: 0.6474
# Epoch 3: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 380s 243ms/step - loss: 1.0006 - accuracy: 0.6474 - val_loss: 1.0020 - val_accuracy: 0.6365
# Epoch 4/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9350 - accuracy: 0.6691
# Epoch 4: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 410s 262ms/step - loss: 0.9350 - accuracy: 0.6691 - val_loss: 0.9202 - val_accuracy: 0.6728
# Epoch 5/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8859 - accuracy: 0.6858
# Epoch 5: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 383s 245ms/step - loss: 0.8859 - accuracy: 0.6858 - val_loss: 0.8815 - val_accuracy: 0.6801
# Epoch 6/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8449 - accuracy: 0.6995
# Epoch 6: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 408s 261ms/step - loss: 0.8449 - accuracy: 0.6995 - val_loss: 0.8740 - val_accuracy: 0.6838
# Epoch 7/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8119 - accuracy: 0.7107
# Epoch 7: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.8119 - accuracy: 0.7107 - val_loss: 0.8905 - val_accuracy: 0.6818
# Epoch 8/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7842 - accuracy: 0.7195
# Epoch 8: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 408s 261ms/step - loss: 0.7842 - accuracy: 0.7195 - val_loss: 0.9160 - val_accuracy: 0.6725
# Epoch 9/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7602 - accuracy: 0.7275
# Epoch 9: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 408s 261ms/step - loss: 0.7602 - accuracy: 0.7275 - val_loss: 0.9083 - val_accuracy: 0.6662
# Epoch 10/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7389 - accuracy: 0.7338
# Epoch 10: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 411s 263ms/step - loss: 0.7389 - accuracy: 0.7338 - val_loss: 0.8595 - val_accuracy: 0.6921
# Epoch 11/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7157 - accuracy: 0.7426
# Epoch 11: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.7157 - accuracy: 0.7426 - val_loss: 0.8695 - val_accuracy: 0.6861
# Epoch 12/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.7490
# Epoch 12: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 404s 258ms/step - loss: 0.6994 - accuracy: 0.7490 - val_loss: 0.8748 - val_accuracy: 0.6927
# Epoch 13/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6829 - accuracy: 0.7547
# Epoch 13: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 408s 261ms/step - loss: 0.6829 - accuracy: 0.7547 - val_loss: 0.9191 - val_accuracy: 0.6688
# Epoch 14/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6688 - accuracy: 0.7605
# Epoch 14: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 378s 242ms/step - loss: 0.6688 - accuracy: 0.7605 - val_loss: 0.8414 - val_accuracy: 0.7025
# Epoch 15/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6546 - accuracy: 0.7628
# Epoch 15: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.6546 - accuracy: 0.7628 - val_loss: 1.0477 - val_accuracy: 0.6239
# Epoch 16/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6401 - accuracy: 0.7685
# Epoch 16: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.6401 - accuracy: 0.7685 - val_loss: 0.8887 - val_accuracy: 0.6948
# Epoch 17/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6247 - accuracy: 0.7741
# Epoch 17: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.6247 - accuracy: 0.7741 - val_loss: 0.8535 - val_accuracy: 0.6959
# Epoch 18/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.7775
# Epoch 18: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 409s 262ms/step - loss: 0.6151 - accuracy: 0.7775 - val_loss: 0.9505 - val_accuracy: 0.6675
# Epoch 19/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6046 - accuracy: 0.7815
# Epoch 19: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 406s 260ms/step - loss: 0.6046 - accuracy: 0.7815 - val_loss: 1.0072 - val_accuracy: 0.6502
# Epoch 20/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.7846
# Epoch 20: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 379s 243ms/step - loss: 0.5931 - accuracy: 0.7846 - val_loss: 0.8385 - val_accuracy: 0.7089
# Epoch 21/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.7889
# Epoch 21: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 406s 260ms/step - loss: 0.5811 - accuracy: 0.7889 - val_loss: 0.8349 - val_accuracy: 0.7117
# Epoch 22/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.7930
# Epoch 22: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 379s 243ms/step - loss: 0.5688 - accuracy: 0.7930 - val_loss: 0.8113 - val_accuracy: 0.7149
# Epoch 23/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5565 - accuracy: 0.7979
# Epoch 23: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 378s 242ms/step - loss: 0.5565 - accuracy: 0.7979 - val_loss: 1.0958 - val_accuracy: 0.6305
# Epoch 24/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.7994
# Epoch 24: saving model to /gdrive/MyDrive/comp8220data/AftermathTest
# 1563/1563 [==============================] - 405s 259ms/step - loss: 0.5496 - accuracy: 0.7994 - val_loss: 0.7986 - val_accuracy: 0.7229
# Epoch 25/40
#  845/1563 [===============>..............] - ETA: 2:26 - loss: 0.5450 - accuracy: 0.8021

# %%
model.load_weights('/gdrive/MyDrive/comp8220data')

# Add a new dense layer with 50 units for 50 classes
model.add(tf.keras.layers.Dense(units=200, activation="relu"))
model.add(tf.keras.layers.Dense(units=50, activation="softmax"))

# %%
model.pop()

# %%
checkpoint_path = "/gdrive/MyDrive/comp8220datafine"
#checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callbackfine = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs = 10, callbacks=[cp_callbackfine], class_weight=class_weight, verbose=1)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - ETA: 0s - loss: 3.2092 - accuracy: 0.2002
# Epoch 1: saving model to /gdrive/MyDrive/comp8220datafine
# 1563/1563 [==============================] - 382s 224ms/step - loss: 3.2092 - accuracy: 0.2002 - val_loss: 2.6625 - val_accuracy: 0.2712
# Epoch 2/10
# 1563/1563 [==============================] - ETA: 0s - loss: 2.4187 - accuracy: 0.3215
# Epoch 2: saving model to /gdrive/MyDrive/comp8220datafine
# 1563/1563 [==============================] - 346s 221ms/step - loss: 2.4187 - accuracy: 0.3215 - val_loss: 3.0366 - val_accuracy: 0.2447
# Epoch 3/10
#  104/1563 [>.............................] - ETA: 4:04 - loss: 2.2868 - accuracy: 0.3531
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-5ffda94a86d1> in <cell line: 1>()
# ----> 1 history = model.fit(train_ds,validation_data=val_ds, epochs = 10, callbacks=[cp_callbackfine], verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.load_weights('/gdrive/MyDrive/comp8220datafine')

# %%
# !unzip -q /gdrive/MyDrive/comp8220data/living-thing-classification-coarse-private.zip
# Out:
# replace privtest_coarse/privtest_coarse.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
test_ds = create_dataset_tf('privtest_coarse/privtest_coarse', fine_grained=False, batch_size=batch_size)

# %%
total_elements = tf.data.experimental.cardinality(test_ds).numpy()
print(total_elements)
# Out:
# 24

# %%
y_pred_fine = model.predict(test_ds)
# Out:
# 24/24 [==============================] - 4s 86ms/step

# %%
y_pred_classes = np.argmax(y_pred_fine, axis=1)

# %%
N = 1500     # num elements in test.csv
privtest_csv = pd.read_csv(root / f"privtest_coarse/privtest_coarse.csv")
privtest_csv.loc[:,"coarse"] = y_pred_classes
#privtest_csv = privtest_csv.drop(columns=['fine'])
pred_file = "/gdrive/MyDrive/comp8220data/47506067-deep-fineprivatedata.csv"  # CHANGE DIRECTORY, FILENAME as appropriate
privtest_csv.to_csv(pred_file)

# %%
data_augmentation = tf.keras.Sequential(
    [tf.keras.layers.RandomFlip(mode="horizontal", seed=42),
     tf.keras.layers.RandomRotation(factor=0.05, seed=42)]
)

# %%
base_model = tf.keras.applications.xception.Xception(weights="imagenet", include_top=False)
avg = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(8, activation="softmax")(avg)
model = tf.keras.Model(inputs=base_model.input, outputs=output)
model.summary()

# %%
for layer in base_model.layers:
  layer.trainable = False

optimizer = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.9)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer = optimizer, metrics=["accuracy"])

# %%
history = model.fit(train_set,validation_data=val_set, epochs = 3, verbose=1)
# Out:
# Epoch 1/3
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-16-a3c8d1e5cd60> in <cell line: 1>()
# ----> 1 history = model.fit(train_set,validation_data=val_set, epochs = 3, verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node model/block1_conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer}}]] [Op:__inference_train_function_7464]

# %% [markdown]
# ## Last Step: Create CSV File With Prediction

# %%
N = 50000     # num elements in test.csv
test_csv = pd.read_csv(root / f"test.csv")
test_csv.loc[:,"coarse"] = predicted_y
test_csv = test_csv.drop(columns=['fine'])
pred_file = "/gdrive/MyDrive/comp8220data/my_test_preds.csv"  # CHANGE DIRECTORY, FILENAME as appropriate
test_csv.to_csv(pred_file)
